# %% [markdown]
# # Exploratory Data Analysis (Andreas/ Crow)

# %%
# Importing packages
import math as math
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn import datasets, linear_model, metrics
import seaborn as sns
plt.style.use('seaborn')
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# Loading the data
file = pd.read_csv('Finalmoviefile.csv')
file.head()
# Out:
#                                            title  year     genres  avg rating  \
# 0  Trip to the Moon, A (Voyage dans la lune, Le)  1902     Action        3.50
# 1                        The Great Train Robbery  1903      Crime        2.50
# 2                             The Electric Hotel  1908  Animation        4.00
# 3                         Birth of a Nation, The  1915      Drama        2.00
# 4                   20,000 Leagues Under the Sea  1916     Action        3.75
#
#                 rating tags
# 0  3.5|4.5|3.0|3.5|3.0  NaN
# 1              4.0|1.0  NaN
# 2                    4  NaN
# 3                    2  NaN
# 4              4.0|3.5  NaN

# %%
# Checking the data. 
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9724 entries, 0 to 9723
# Data columns (total 6 columns):
# title         9724 non-null object
# year          9724 non-null object
# genres        9724 non-null object
# avg rating    9724 non-null float64
# rating        9724 non-null object
# tags          1554 non-null object
# dtypes: float64(1), object(5)
# memory usage: 455.9+ KB

# %%
# Summary of data.
file.describe()
# Out:
#         avg rating
# count  9724.000000
# mean      3.262644
# std       0.869882
# min       0.500000
# 25%       2.800000
# 50%       3.420000
# 75%       3.910000
# max       5.000000

# %%
# Plotting year (x) vs. average rating (y). 
plt.scatter(file['year'], file['avg rating'], marker='o')
plt.xlabel("year")
plt.ylabel("avg rating")
plt.show()

# %%
#Grouping data by category genres
file.groupby(['genres']).count()
# Out:
#                     title  year  avg rating  rating  tags
# genres
# (no genres listed)     34    34          34      34     1
# Action               1828  1828        1828    1828   235
# Adventure             652   652         652     652   118
# Animation             297   297         297     297    37
# Children              197   197         197     197    27
# Comedy               2776  2776        2776    2776   398
# Crime                 534   534         534     534   102
# Documentary           385   385         385     385    63
# Drama                2218  2218        2218    2218   486
# Fantasy                42    42          42      42     3
# Film-Noir              12    12          12      12     5
# Horror                468   468         468     468    38
# Musical                23    23          23      23     7
# Mystery                48    48          48      48    12
# Romance                38    38          38      38     8
# Sci-Fi                 62    62          62      62     4
# Thriller               83    83          83      83     8
# War                     4     4           4       4     0
# Western                23    23          23      23     2
